# %% [markdown]
# ##### Hierarchical clustering: If you have poinst on data points you will get clusters like K mean but process is different.
# ##### There are two types of hierarchical clustering:
# 1. Agglomeratuve: Bottom up approach.
# 2. Divisive: Top down approach
#
# ###### Steps of Agglomerative HC:
# 1. Make each data point a single point cluster => that forms N clusters
# 2. Take the two closest data points and make them one cluster: that form N-1 Clusters.
# 3. Take the two more closest and make them one cluster N-2
# 4. Repear STEP 3 until there is one cluster left
# 5. Model is ready
# 6. Calculate distance using euclidean distance.
# ##### Closest of cluster: How you measure closest of cluster.
# #### Distance between two cluster
# 1. Take closest point
# 2. Furtherst point
# 3. Average distance
# 4. Distance between the centroids
#
# * In heirarchical cluster the distance betwen two cluster is crucial element.
# * How you define.
#
# ##### How do Dendograms Works:
# * How do we get actual cluster
# * How do we get right number of clusters
# * Dendograms use for this.
# * Dendograms works as memory for HC.
# * Signify the two connected points on dendogram graph
#
# #####  How to get maximum value using dendograms, how to use this
# * Look at horizontal level and calculate the threshold or dissimilarity.
# * Anything above the threshold we dont want that one.
# * Count how many lines the threshold crosses then same number of cluster.
#
# ##### How dendogram prove to great guide to select optimal number of clusters.
#
# * Any line which cannot cross the thresold will consider

# %%
# Import the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_csv('Mall_Customers.csv')
x = dataset.iloc[:, [3, 4]].values

# %%
x
# Out:
# array([[ 15,  39],
#        [ 15,  81],
#        [ 16,   6],
#        [ 16,  77],
#        [ 17,  40],
#        [ 17,  76],
#        [ 18,   6],
#        [ 18,  94],
#        [ 19,   3],
#        [ 19,  72],
#        [ 19,  14],
#        [ 19,  99],
#        [ 20,  15],
#        [ 20,  77],
#        [ 20,  13],
#        [ 20,  79],
#        [ 21,  35],
#        [ 21,  66],
#        [ 23,  29],
#        [ 23,  98],
#        [ 24,  35],
#        [ 24,  73],
#        [ 25,   5],
#        [ 25,  73],
#        [ 28,  14],
#        [ 28,  82],
#        [ 28,  32],
#        [ 28,  61],
#        [ 29,  31],
#        [ 29,  87],
#        [ 30,   4],
#        [ 30,  73],
#        [ 33,   4],
#        [ 33,  92],
#        [ 33,  14],
#        [ 33,  81],
#        [ 34,  17],
#        [ 34,  73],
#        [ 37,  26],
#        [ 37,  75],
#        [ 38,  35],
#        [ 38,  92],
#        [ 39,  36],
#        [ 39,  61],
#        [ 39,  28],
#        [ 39,  65],
#        [ 40,  55],
# ...

# %%
# Using the dendrogram to find the optimal number of clusters
# import dendogram from scipy
import scipy.cluster.hierarchy as sch
# add hierarchy technique, minimum variance: ward
dendogram = sch.dendrogram(sch.linkage(x, method='ward'))
plt.title("Dendogram")
plt.xlabel("Customers")
plt.ylabel("")
# Out:
# Text(0, 0.5, '')

# %%
# Training the Hierarchical Clustering model on the dataset
from sklearn.cluster import AgglomerativeClustering
hc = AgglomerativeClustering(n_clusters=5, affinity='euclidean', linkage='ward')
y_hc = hc.fit_predict(x)

# %%
# Visualize the result
plt.scatter(x[y_hc == 0, 0], x[y_hc == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(x[y_hc == 1, 0], x[y_hc == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(x[y_hc == 2, 0], x[y_hc == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(x[y_hc == 3, 0], x[y_hc == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(x[y_hc == 4, 0], x[y_hc == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5')
plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()
