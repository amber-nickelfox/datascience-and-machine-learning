# %% [markdown]
# ##### Polynomial Regression
# 1. Data preprocessing
# 2. Split (In this case skip this)
# 3. Train
# 4. Test

# %%
# Import library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
dataset = pd.read_csv('Position_Salaries.csv')
x = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:,-1].values

# %%
# Training linear regression model on whole dataser
from sklearn.linear_model import LinearRegression
lin_regressor = LinearRegression()
lin_regressor.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Training the polynomial regression model on whole dataset
# Polynomial feature preprocessing
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=4)
# new matrix of features
x_poly = poly_reg.fit_transform(x)
lin_reg2 = LinearRegression()
lin_reg2.fit(x_poly, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Visualize the linear regression results
# Not well adapted
plt.scatter(x,y, color="red")
plt.plot(x, lin_regressor.predict(x), color="yellow")
plt.title("Truth or Bluff")
plt.xlabel("Position label")
plt.ylabel("Salary")
# Out:
# Text(0, 0.5, 'Salary')

# %%
# Visualize the polynomila regression (for higher resolution and smoother curve)
plt.scatter(x,y, color="red")
plt.plot(x, lin_reg2.predict(x_poly), color="yellow")
plt.title("Truth or Bluff (Polynomial regression)")
plt.xlabel("Position label")
plt.ylabel("Salary")
plt.show()

# %%
# Predicting new result with polynomial regression
