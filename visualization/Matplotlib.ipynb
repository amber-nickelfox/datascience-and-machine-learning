# %%
# Matplotlib for plotting library

# %%
import matplotlib.pyplot as plt

# %%
# If using jupyter notebook use, for see the plot you create.
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0,5,11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
# 2 ways to create matplotlib
# functional and object oriented

# %%
# FUNCTIONAL

plt.plot(x,y)
plt.show() # not necessary in jupyter notebook

# %%
plt.plot(x,y)
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title("Title")
# Out:
# Text(0.5, 1.0, 'Title')

# %%
# Multiplot
plt.subplot(1,2,1)
plt.plot(x,y, 'r')

plt.subplot(1,2,2)
plt.plot(y,x, 'b')

# %%
# Object oriented for matplotlib
# create a figure object
fig = plt.figure()
# left bottom width height
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])
# Here we create own canvas
axes.plot(x,y)
axes.set_xlabel('X label')
axes.set_ylabel('Y Label')
axes.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
# figure object
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
# create sub figure
axes2 = fig.add_axes([0.4, 0.7, 0.4, 0.1])
axes1.plot(x,y)
axes1.set_title('Outer')
axes2.plot(y,x)
axes2.set_title('Inner')
# Out:
# Text(0.5, 1.0, 'Inner')

# %%
# create subplot using object oriented

# %%
fig, axes = plt.subplots(nrows=3, ncols=2)
# axes.plot(x,y)
plt.tight_layout()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
# axes.plot(x,y)

# %%
# axes is an array of subplots
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f5502263828>,
# ...
#       dtype=object)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
for current in axes:
    current.plot(x,y)
    current.plot(y,x)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].plot(x,y)
axes[0].set_title('First plot')
axes[1].plot(y,x)
axes[1].set_title('second plot')
# Out:
# Text(0.5, 1.0, 'second plot')

# %%
# Figure size and DPI
# DPI: Dots per axes
fig = plt.figure(figsize=(8,2))
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
# Figure size and DPI
# DPI: Dots per axes
fig,ax = plt.subplots(nrows=1, ncols=1, figsize=(8,2))
ax.plot(x,y)

# %%
# save a figure (high quality image pdf, png, jpeg)

# %%
fig.savefig('my_picture.png', dpi=200)

# %%
# legend
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x, x**2, label='X squared')
ax.plot(x, x**3, label='Y squared')
ax.legend(loc=0)

# %%
# setting colors
fig = plt.figure()
axes = fig.add_axes([0,0,1,1])
# also put RGB hex color
axes.plot(x,y, color='red', linewidth=3, alpha=0.5)

# %%
# setting colors
fig = plt.figure()
axes = fig.add_axes([0,0,1,1])
# also put RGB hex color
axes.plot(x,y, color='red', linewidth=3, linestyle='--')

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
# setting colors
fig = plt.figure()
axes = fig.add_axes([0,0,1,1])
# also put RGB hex color
axes.plot(x,y, color='red', linewidth=3, marker='o', markersize=10,
         markerfacecolor='yellow', markeredgecolor='green')

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x+1, color="red", linewidth=0.25)
ax.plot(x, x+2, color="red", linewidth=0.50)
ax.plot(x, x+3, color="red", linewidth=1.00)
ax.plot(x, x+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+5, color="green", lw=3, linestyle='-')
ax.plot(x, x+6, color="green", lw=3, ls='-.')
ax.plot(x, x+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')

# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

axes[0].plot(x, x**2, x, x**3)
axes[0].set_title("default axes ranges")

axes[1].plot(x, x**2, x, x**3)
axes[1].axis('tight')
axes[1].set_title("tight axes")

axes[2].plot(x, x**2, x, x**3)
axes[2].set_ylim([0, 60])
axes[2].set_xlim([2, 5])
axes[2].set_title("custom axes range");

# %%
# special type plot
plt.scatter(x,y)

# %%
"""
There are many specialized plots we can create, such as barplots, histograms, scatter plots, and much more. Most of these type of plots we will actually create using seaborn, a statistical plotting library for Python. But here are a few examples of these type of plots:
"""
# Out:
# '\nThere are many specialized plots we can create, such as barplots, histograms, scatter plots, and much more. Most of these type of plots we will actually create using seaborn, a statistical plotting library for Python. But here are a few examples of these type of plots:\n'

# %%
from random import sample
data = sample(range(1,1000), 100)
data
# Out:
# [453,
#  236,
#  81,
#  919,
#  77,
#  450,
#  314,
#  420,
#  458,
#  692,
#  117,
#  918,
#  649,
#  200,
#  31,
#  83,
#  346,
#  44,
#  356,
#  706,
#  112,
#  511,
#  463,
#  816,
#  777,
#  569,
#  103,
#  9,
#  671,
#  154,
#  208,
#  575,
#  150,
#  512,
#  712,
#  351,
#  180,
#  424,
#  870,
#  808,
#  34,
#  476,
#  519,
#  145,
#  412,
#  32,
#  50,
#  690,
#  93,
#  214,
#  796,
#  302,
#  587,
#  75,
#  197,
#  135,
#  427,
#  922,
#  409,
#  920,
#  215,
#  693,
#  877,
#  566,
#  551,
#  968,
#  244,
#  844,
#  814,
#  95,
#  976,
#  212,
#  682,
#  481,
#  973,
#  619,
#  617,
#  666,
#  480,
#  464,
#  756,
#  893,
#  283,
#  743,
#  562,
#  664,
#  985,
#  276,
#  727,
#  977,
#  929,
#  561,
#  917,
#  350,
#  468,
#  132,
#  678,
#  677,
#  960,
#  601]

# %%
plt.hist(data)
# Out:
# (array([13., 10.,  8.,  6., 14., 10., 12.,  7.,  7., 13.]),
#  array([  9. , 106.6, 204.2, 301.8, 399.4, 497. , 594.6, 692.2, 789.8,
#         887.4, 985. ]),
#  <a list of 10 Patch objects>)
